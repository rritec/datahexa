# %%
pip install PyPDF2 # installing necessary modules for PDF comparison from anaconda prompt
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install PyPDF2 # installing necessary modules for PDF comparison from anaconda prompt
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
import PyPDF2

# %%
hindu=open("Hindu.pdf","rb")

# %%
hindu
# Out:
# <_io.BufferedReader name='Hindu.pdf'>

# %%
ie=open("Indian_Express.pdf","rb")

# %%
ie
# Out:
# <_io.BufferedReader name='Indian_Express.pdf'>

# %%
hindu_reader = PyPDF2.PdfFileReader(hindu)

# %%
ie_reader = PyPDF2.PdfFileReader(ie)

# %%
print("Number of Pages in Hindu News Paper: ",hindu_reader.numPages) # number of pages in hindu reader
# Out:
# Number of Pages in Hindu News Paper:  18

# %%
print("Number of Pages in Indian Express News Paper: ",ie_reader.numPages) # number of pages in indian express
# Out:
# Number of Pages in Indian Express News Paper:  22

# %%
page1_hindu=hindu_reader.getPage(0)
a =[(page1_hindu.extractText())]

# %%
b=str(a) # converting list to string

# %%
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import nltk

# %%
nltk.download('stopwords') # importing stop words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Raja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
word=word_tokenize(b)

# %%
word
# Out:
# ['[',
#  "'",
#  '#',
#  '70929CMYKAND-NDEwednesday',
#  ',',
#  'march',
#  '27',
#  ',',
#  '2019\\nDelhiCity',
#  'Edition\\n24',
#  'pages\\nO†10.00Printed',
#  'at\\n.Chennai.Coimbatore\\n.Bengaluru\\n.Hyderabad.Madurai.Noida\\n.Visakhapatnam\\n.Thiruvananthapuram\\n.Kochi.Vijayawada\\n.Mangaluru\\n.Tiruchirapalli\\n.Kolkata\\n.Hubballi.Mohali.Malappuram.Mumbai.Tirupati\\n.lucknow\\n.cuttack\\n.patna\\nfollow',
#  'us',
#  ':',
#  '\\nthehindu.com\\n\\nfacebook.com/thehindu\\n\\ntwitter.com/the_hindu\\nShamima',
#  'Kauser',
#  ',',
#  'mother',
#  'of\\nIshrat',
#  'Jahan',
#  ',',
#  'who',
#  'was',
#  'killed\\nalong',
#  'with',
#  'three',
#  'others',
#  'in',
#  'an\\nalleged',
#  'fake',
#  'encounter',
#  'in\\nGujarat',
#  'in',
#  '2004',
#  ',',
#  'has',
#  'ap-\\nproached',
#  'the',
#  'local',
#  'CBI',
#  'court\\nhere',
#  'challenging',
#  'the',
#  'Gujarat\\ngovernment™s',
#  'refusal',
#  'to\\ngrant',
#  'sanction',
#  'to',
#  'prosecute\\nformer',
# ...

# %%
from collections import Counter
from nltk.stem import WordNetLemmatizer

# %%
counters= Counter(word_tokenize(b))

# %%
counters
# Out:
# Counter({'[': 2,
#          "'": 2,
#          '#': 1,
#          '70929CMYKAND-NDEwednesday': 1,
#          ',': 149,
#          'march': 1,
#          '27': 1,
#          '2019\\nDelhiCity': 1,
#          'Edition\\n24': 1,
#          'pages\\nO†10.00Printed': 1,
#          'at\\n.Chennai.Coimbatore\\n.Bengaluru\\n.Hyderabad.Madurai.Noida\\n.Visakhapatnam\\n.Thiruvananthapuram\\n.Kochi.Vijayawada\\n.Mangaluru\\n.Tiruchirapalli\\n.Kolkata\\n.Hubballi.Mohali.Malappuram.Mumbai.Tirupati\\n.lucknow\\n.cuttack\\n.patna\\nfollow': 1,
#          'us': 1,
#          ':': 6,
#          '\\nthehindu.com\\n\\nfacebook.com/thehindu\\n\\ntwitter.com/the_hindu\\nShamima': 1,
#          'Kauser': 1,
#          'mother': 2,
#          'of\\nIshrat': 1,
#          'Jahan': 1,
#          'who': 9,
#          'was': 9,
#          'killed\\nalong': 1,
#          'with': 10,
#          'three': 3,
#          'others': 2,
#          'in': 51,
#          'an\\nalleged': 1,
#          'fake': 1,
# ...

# %%
counters.most_common(50)
# Out:
# [(',', 149),
#  ('the', 90),
#  ('.', 53),
#  ('in', 51),
#  ('of', 44),
#  ('to', 40),
#  ('and', 38),
#  ('a', 32),
#  ('on', 17),
#  ('“', 16),
#  ('that', 16),
#  ('by', 12),
#  ('\\nAPAGE', 11),
#  ('(', 11),
#  (')', 11),
#  ('with', 10),
#  ('had', 10),
#  ('who', 9),
#  ('was', 9),
#  ('%', 9),
#  ('police', 8),
#  ('\\nThe', 8),
#  ('as', 8),
#  ('for', 8),
#  ('said', 8),
#  ('CBI', 7),
#  ('be', 7),
#  ('at', 7),
#  ('his', 7),
#  ('are', 7),
#  (':', 6),
#  ('their', 6),
#  ('have', 6),
#  ('them', 6),
#  ('an', 6),
#  ('after', 6),
#  ('cases', 6),
#  ('from', 6),
#  (';', 6),
#  ('Š', 6),
#  ('not', 6),
#  ('court', 5),
#  ('report', 5),
#  ('is', 5),
#  ('or', 5),
#  ('’', 5),
#  ('has', 4),
#  ('were', 4),
#  ('government™s', 4),
#  ('Mr.', 4)]

# %%
# Make a set of unique tokens in the entire scene: unique_tokens
unique_tokens = set(word_tokenize(b))
# Print the unique tokens result
print(unique_tokens)
# Out:
# {'Mr.', 'dues\\nNearly', 'to-\\ntal', 'States', 'wife\\nAnita', 'into\\nthe', 'house', 'those', 'enjoys\\nan', 'ran', 'SHIFT', 'man-\\nhandled', 'cancellations', 'secretary', '.', '5\\nFormer', 'asking', 'fully', '\\nlater', 'obstruct\\njudicial', 'Taisi', 'DELHI', 'killed', 'out\\ncontesting', 'should', '17\\nDELHI', 'Kolkata\\nresidence', '28', 'air-\\nfares', ']', 'ex-\\npected', 'allegations', 'But', 'on\\nhow', 'party', 'airline™s', 'ground', 'criti-\\ncism', 'governance', 'form-\\ner', 'that\\ninstructions', 'Rajoura', 'packing', 'entering', 'Selvaperumal\\nNagar', '\\nﬁIn', 'audience', 'particular', '‚The', '35', 'wrong™', 'engaged', 'things', '\\nDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD', 'Bengal', 'his\\ntwo', 'beef', 'Manohar', 'eet', 'popular', '\\nﬁObjectives', 'lm', 'motionless\\nin', 'net\\nrate.\\nOn', 'surveys', 'shot', 'refused', 'ON', 'a\\ncontempt', 'aircraft', 'pre-\\nvious', 'half-a-million\\nsubscribers', 'sold-out', 'op-\\nposed', '31', 'worker', 'get', 't
# ...

# %%
lower_tokens = [t.lower() for t in word]

# %%
lower_tokens # converting into alphabets ?
# Out:
# ['[',
#  "'",
#  '#',
#  '70929cmykand-ndewednesday',
#  ',',
#  'march',
#  '27',
#  ',',
#  '2019\\ndelhicity',
#  'edition\\n24',
#  'pages\\no†10.00printed',
#  'at\\n.chennai.coimbatore\\n.bengaluru\\n.hyderabad.madurai.noida\\n.visakhapatnam\\n.thiruvananthapuram\\n.kochi.vijayawada\\n.mangaluru\\n.tiruchirapalli\\n.kolkata\\n.hubballi.mohali.malappuram.mumbai.tirupati\\n.lucknow\\n.cuttack\\n.patna\\nfollow',
#  'us',
#  ':',
#  '\\nthehindu.com\\n\\nfacebook.com/thehindu\\n\\ntwitter.com/the_hindu\\nshamima',
#  'kauser',
#  ',',
#  'mother',
#  'of\\nishrat',
#  'jahan',
#  ',',
#  'who',
#  'was',
#  'killed\\nalong',
#  'with',
#  'three',
#  'others',
#  'in',
#  'an\\nalleged',
#  'fake',
#  'encounter',
#  'in\\ngujarat',
#  'in',
#  '2004',
#  ',',
#  'has',
#  'ap-\\nproached',
#  'the',
#  'local',
#  'cbi',
#  'court\\nhere',
#  'challenging',
#  'the',
#  'gujarat\\ngovernment™s',
#  'refusal',
#  'to\\ngrant',
#  'sanction',
#  'to',
#  'prosecute\\nformer',
# ...

# %%
alpha_only = [t for t in lower_tokens if t.isalpha()]
alpha_only
# Out:
# ['march',
#  'us',
#  'kauser',
#  'mother',
#  'jahan',
#  'who',
#  'was',
#  'with',
#  'three',
#  'others',
#  'in',
#  'fake',
#  'encounter',
#  'in',
#  'has',
#  'the',
#  'local',
#  'cbi',
#  'challenging',
#  'the',
#  'refusal',
#  'sanction',
#  'to',
#  'police',
#  'and',
#  'amin',
#  'by',
#  'the',
#  'gujarat',
#  'refused',
#  'to',
#  'to',
#  'prosecute',
#  'the',
#  'it',
#  'reportedly',
#  'they',
#  'were',
#  'doing',
#  'their',
#  'cial',
#  'duty',
#  'and',
#  'therefore',
#  'be',
#  'prosecuted',
#  'her',
#  'application',
#  'submitted',
#  'that',
#  'would',
#  'have',
#  'serious',
#  'and',
#  'proceedings',
#  'she',
#  'contended',
#  'that',
#  'the',
#  'cbi',
#  'court',
#  'had',
#  'earlier',
#  'the',
#  'application',
#  'of',
#  'and',
#  'amin',
#  'ground',
#  'that',
#  'there',
#  'evidence',
#  'against',
#  'them',
#  'crime',
#  'august',
#  'rejected',
#  'the',
#  'the',
#  'killed',
#  'in',
#  'an',
#  'held',
#  'that',
# ...

# %%
from nltk.corpus import stopwords

# %%
no_stops = [t for t in alpha_only if t not in stopwords.words('english')]
no_stops
# Out:
# ['march',
#  'us',
#  'kauser',
#  'mother',
#  'jahan',
#  'three',
#  'others',
#  'fake',
#  'encounter',
#  'local',
#  'cbi',
#  'challenging',
#  'refusal',
#  'sanction',
#  'police',
#  'amin',
#  'gujarat',
#  'refused',
#  'prosecute',
#  'reportedly',
#  'cial',
#  'duty',
#  'therefore',
#  'prosecuted',
#  'application',
#  'submitted',
#  'would',
#  'serious',
#  'proceedings',
#  'contended',
#  'cbi',
#  'court',
#  'earlier',
#  'application',
#  'amin',
#  'ground',
#  'evidence',
#  'crime',
#  'august',
#  'rejected',
#  'killed',
#  'held',
#  'prima',
#  'facie',
#  'encounter',
#  'ﬂ',
#  'stated',
#  'moved',
#  'vrinda',
#  'grover',
#  'court',
#  'also',
#  'sought',
#  'copy',
#  'report',
#  'grant',
#  'sanction',
#  'moved',
#  'court',
#  'asking',
#  'dropped',
#  'following',
#  'sanction',
#  'mother',
#  'moves',
#  'cbi',
#  'metro',
#  'supreme',
#  'court',
#  'asked',
#  'whether',
#  'close',
#  'eyes',
#  'mattersﬂ',
#  'come',
# ...

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('wordnet') # download word net
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Raja\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wordnet_lemmatizer=WordNetLemmatizer()

# %%
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stops]
lemmatized
# Out:
# ['march',
#  'u',
#  'kauser',
#  'mother',
#  'jahan',
#  'three',
#  'others',
#  'fake',
#  'encounter',
#  'local',
#  'cbi',
#  'challenging',
#  'refusal',
#  'sanction',
#  'police',
#  'amin',
#  'gujarat',
#  'refused',
#  'prosecute',
#  'reportedly',
#  'cial',
#  'duty',
#  'therefore',
#  'prosecuted',
#  'application',
#  'submitted',
#  'would',
#  'serious',
#  'proceeding',
#  'contended',
#  'cbi',
#  'court',
#  'earlier',
#  'application',
#  'amin',
#  'ground',
#  'evidence',
#  'crime',
#  'august',
#  'rejected',
#  'killed',
#  'held',
#  'prima',
#  'facie',
#  'encounter',
#  'ﬂ',
#  'stated',
#  'moved',
#  'vrinda',
#  'grover',
#  'court',
#  'also',
#  'sought',
#  'copy',
#  'report',
#  'grant',
#  'sanction',
#  'moved',
#  'court',
#  'asking',
#  'dropped',
#  'following',
#  'sanction',
#  'mother',
#  'move',
#  'cbi',
#  'metro',
#  'supreme',
#  'court',
#  'asked',
#  'whether',
#  'close',
#  'eye',
#  'mattersﬂ',
#  'come',
#  'perusing',
# ...

# %%
counters1= Counter(lemmatized)

# %%
counters1
# Out:
# Counter({'march': 1,
#          'u': 1,
#          'kauser': 1,
#          'mother': 2,
#          'jahan': 1,
#          'three': 3,
#          'others': 2,
#          'fake': 1,
#          'encounter': 2,
#          'local': 1,
#          'cbi': 7,
#          'challenging': 1,
#          'refusal': 1,
#          'sanction': 3,
#          'police': 8,
#          'amin': 2,
#          'gujarat': 1,
#          'refused': 1,
#          'prosecute': 1,
#          'reportedly': 2,
#          'cial': 1,
#          'duty': 1,
#          'therefore': 1,
#          'prosecuted': 1,
#          'application': 3,
#          'submitted': 1,
#          'would': 3,
#          'serious': 2,
#          'proceeding': 1,
#          'contended': 1,
#          'court': 8,
#          'earlier': 1,
#          'ground': 1,
#          'evidence': 1,
#          'crime': 1,
#          'august': 1,
#          'rejected': 1,
#          'killed': 2,
#          'held': 1,
#          'prima': 1,
# ...

# %%
print(counters1.most_common(10))
# Out:
# [('case', 9), ('police', 8), ('court', 8), ('said', 8), ('cbi', 7), ('party', 7), ('š', 6), ('report', 5), ('chief', 5), ('state', 5)]

# %%
d=counters1.most_common(10)
print(d)
# Out:
# [('case', 9), ('police', 8), ('court', 8), ('said', 8), ('cbi', 7), ('party', 7), ('š', 6), ('report', 5), ('chief', 5), ('state', 5)]

# %%
type(d)
# Out:
# list

# %%
from matplotlib import pyplot as plt
num_bins = 10
n, bins, patches = plt.hist(d, num_bins, facecolor='blue', alpha=6)
