# %% [markdown]
# ## NATURAL LANGUAGE UNDERSTANDING/PROCESSING

# %% [markdown]
# ### Excercise 1# sentence Tokenization

# %%
re.split

# %%
import re

# %%
my_string = """Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences? 
Or perhaps, all 19 words?"""

# %%
pattern = r"[.?]"

# %%
re.split(pattern=pattern,string=my_string)
# Out:
# ["Let's write RegEx!  Won't that be fun",
#  '  I sure think so',
#  '  Can you find 4 sentences',
#  ' \nOr perhaps, all 19 words',
#  '']

# %%
pattern = r"[.?!]"

# %%
re.split(pattern=pattern,string=my_string)
# Out:
# ["Let's write RegEx",
#  "  Won't that be fun",
#  '  I sure think so',
#  '  Can you find 4 sentences',
#  ' \nOr perhaps, all 19 words',
#  '']

# %%
from nltk.tokenize import sent_tokenize #sent_tokenize(text, language='english')

# %%
sent_tokenize
# Out:
# <function nltk.tokenize.sent_tokenize(text, language='english')>

# %% [markdown]
# ### Excercise#2 First Letter Capital

# %%
#find all caitalized words from my_string and pringt the result
capitalized_words=r"[A-Z]w+"

# %%
re.findall #re.findall(pattern, string, flags=0)
# Out:
# <function re.findall(pattern, string, flags=0)>

# %%
re.findall(pattern="\d", string="he has 8 dogs and 11 cats")
# Out:
# ['8', '1', '1']

# %%
re.findall(pattern="\d+", string="he has 8 dogs and 11 cats")# observe output difference
# Out:
# ['8', '11']

# %%
re.findall(pattern="[a-z]+", string="he has 8 dogs and 11 cats")
# Out:
# ['he', 'has', 'dogs', 'and', 'cats']

# %%
re.findall(pattern="[a-z]+ |\d+", string="he has 8 dogs and 11 cats")
# Out:
# ['he ', 'has ', '8', 'dogs ', 'and ', '11']

# %% [markdown]
# ### capture upto comma

# %%
my_str = "life, is beautiful"

# %%
pwd
# Out:
# 'C:\\Users\\ben_e\\Documents\\01 Jupyter Python Files\\Level 07'

# %%
import spacy

# %%
nlp = spacy.load('en')

# %%
type(nlp)

# %%
type(spacy)

# %%
import os

# %%
os.getcwd

# %%
text = """Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences? 
Or perhaps, all 19 words?"""
print(text)
# Out:
# Let's write RegEx!  Won't that be fun?  I sure think so.  Can you find 4 sentences?
# Or perhaps, all 19 words?

# %%
re.split(r'[.?!]',text)
# Out:
# ["Let's write RegEx",
#  "  Won't that be fun",
#  '  I sure think so',
#  '  Can you find 4 sentences',
#  ' \nOr perhaps, all 19 words',
#  '']

# %%
print(re.findall(r'[\d]+',text))
# Out:
# ['4', '19']

# %%
from nltk import word_tokenize
from nltk import sent_tokenize

# %%
text1 = "All is well. Life is beautiful"

# %%
text1_word_token = word_tokenize(text1)
text1_token
# Out:
# ['All', 'is', 'well', '.', 'Life', 'is', 'beautiful']

# %%
text1_sent_token = sent_tokenize(text1)
text1_sent_token
# Out:
# ['All is well.', 'Life is beautiful']

# %%
text2 = "I like data science. I like RRITEC Training"

# %%
unique_token = set(word_tokenize(text2))
unique_token
# Out:
# {'.', 'I', 'RRITEC', 'Training', 'data', 'like', 'science'}

# %%
from nltk.corpus import

# %%
file = reuters.fileids()
#print(file)

# %%
words = reuters.words('test/14826')
print(words)
# Out:
# ['ASIAN', 'EXPORTERS', 'FEAR', 'DAMAGE', 'FROM', 'U', ...]

# %%
reutersGenres = reuters.categories()
print(reutersGenres)
# Out:
# ['acq', 'alum', 'barley', 'bop', 'carcass', 'castor-oil', 'cocoa', 'coconut', 'coconut-oil', 'coffee', 'copper', 'copra-cake', 'corn', 'cotton', 'cotton-oil', 'cpi', 'cpu', 'crude', 'dfl', 'dlr', 'dmk', 'earn', 'fuel', 'gas', 'gnp', 'gold', 'grain', 'groundnut', 'groundnut-oil', 'heat', 'hog', 'housing', 'income', 'instal-debt', 'interest', 'ipi', 'iron-steel', 'jet', 'jobs', 'l-cattle', 'lead', 'lei', 'lin-oil', 'livestock', 'lumber', 'meal-feed', 'money-fx', 'money-supply', 'naphtha', 'nat-gas', 'nickel', 'nkr', 'nzdlr', 'oat', 'oilseed', 'orange', 'palladium', 'palm-oil', 'palmkernel', 'pet-chem', 'platinum', 'potato', 'propane', 'rand', 'rape-oil', 'rapeseed', 'reserves', 'retail', 'rice', 'rubber', 'rye', 'ship', 'silver', 'sorghum', 'soy-meal', 'soy-oil', 'soybean', 'strategic-metal', 'sugar', 'sun-meal', 'sun-oil', 'sunseed', 'tea', 'tin', 'trade', 'veg-oil', 'wheat', 'wpi', 'yen', 'zinc']

# %%
for w in reuters.words(categories=['bop','cocoa']):
    print(w+' ',end='')
    if(w is '.'):
        print()
# Out:
# SOUTH KOREA MOVES TO SLOW GROWTH OF TRADE SURPLUS South Korea ' s trade surplus is growing too fast and the government has started taking steps to slow it down , Deputy Prime Minister Kim Mahn - je said .
# He told a press conference the government planned to increase investment , speed up the opening of the local market to foreign imports and gradually adjust its currency to hold the surplus " at a proper level ." But he said the government would not allow the won to appreciate too much in a short period of time .
# South Korea has been under pressure from Washington to revalue the won .
# The U .
# S .
# Wants South Korea to cut its trade surplus with the U .
# S ., Which rose to 7 .
# 4 billion dlrs in 1986 from 4 .
# 3 billion dlrs in 1985 .
# Kim , who is also economic planning minister , said prospects were bright for the South Korean economy , but the government would try to hold the current account surplus to around five billion dlrs a year for the next five years .
# ...
